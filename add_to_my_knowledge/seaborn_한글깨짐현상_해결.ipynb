# %% [markdown]
# <a href="https://colab.research.google.com/github/Leena-GO/Self-study/blob/main/add_to_my_knowledge/seaborn_%ED%95%9C%EA%B8%80%EA%B9%A8%EC%A7%90%ED%98%84%EC%83%81_%ED%95%B4%EA%B2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # matplotlib과 seaborn으로 시각화를 할 때 한글이 깨지는 현상

# %% [markdown]
# - 어제 '상관분석'을 하게 되어서, 한 블로그를 들어가보게 되었다.
# - heatmap으로 시각화를 하여 상관분석을 하는 모습이 인상적이라, 나도 따라해보다가 정리의 필요성을 느끼고 정리를 약소하게나마 해본다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - 우선 임시의 데이터를 가지고 DataFrame을 만들어준다.
# - numpy로 random하게 값을 뽑아주자.

# %%
test = pd.DataFrame(np.random.randint(0,100,size = (15,15)), columns = list('가나다라마바사아자차카타파하감'), index = list('가갸거겨고교구규그기나냐너녀노'))

# %%
test
# Out:
#     가   나   다   라   마   바   사   아   자   차   카   타   파   하   감
# 가  83  83  14  29  71  50   4  29  27   0  13  30  98  61  20
# 갸  47  67  88  15  60  36  16   2  43   8  64   4  98  77  62
# 거  74  46  57   6  37  74  81  90  37  72  73  91  59  15  37
# 겨  45  65  33   6  54  31   1  14  71  20  35  24  15  56   3
# 고  90  79  90   1  13  45  68  43  80  96  54  69   4  67  67
# 교  24  81  91  89  36  28  94  69  56  55  80   1  63   9  49
# 구   7  58  86  17  66  65  58   4  77  53  53  42  83  95   7
# 규  48  38  64  76  18   0  63  94  23  96  32  20  33  10  39
# 그  98  64  63  22   8  84  86  95  31  59  31  37  37  79  59
# 기  50  76  83  71   8  51  53  67  81  45  75  51  30  45  55
# 나   1  61  99  63   4  85  55  47  21  57  24  55  86  60   6
# 냐  86  54  23  68  28  52  35  23  58  89  53  98   7  13  28
# 너  85  65  56  20  43  82  92  66  96  20  85  83  29  20  94
# 녀   0  65  29  66  65  88  17  65  91  48  75  14  56  29  16
# ...

# %% [markdown]
# - 아무 처리도 하지 않고, 우선 heatmap을 그려보자.

# %%
df_heatmap = sns.heatmap(test, cbar = True, annot = True, annot_kws = {'size':20}, square = True, cmap = 'Reds')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45796 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46972 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47560 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# - 이렇게 만들어버리면, 네모 칸 안에 있는 글씨는 글씨대로 난리가 나고 바깥에 있는 한글은 다 깨지게 된다.
#
# - 이 문제들을 하나하나 해결해보자.

# %% [markdown]
# ## 1. 한글 깨짐 현상 해결
# - 참고: [jonsyou.log](https://velog.io/@jonsyou/colabsetting1)

# %% [markdown]
# ### 1) 설치되어있는 폰트 확인

# %%
import matplotlib.font_manager as fm

font_list = [font.name for font in fm.fontManager.ttflist] ; font_list
# Out:
# ['STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Serif Display',
#  'STIXSizeTwoSym',
#  'cmss10',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'cmtt10',
#  'cmsy10',
#  'DejaVu Serif',
#  'DejaVu Sans Display',
#  'cmmi10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Liberation Mono',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Humor Sans',
# ...

# %% [markdown]
# - 확인해보니, 한글을 지원하는 폰트가 Colab에서는 보이지 않는다.
# - 나눔폰트를 설치하는 코드를 붙여 넣고 실행한다.

# %% [markdown]
# ### 2) Colab에서 한글폰트를 사용할 수 있는 코드 실행하기

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  


# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %% [markdown]
# - 설치가 완료되면, Colab 런타임을 재시작해준다.

# %%
# plt.rcParams['font.family'] = 'NanumBarunGothic'

# %%
sns.heatmap(test, cbar = True, annot = True, annot_kws = {'size':20}, square = True, cmap = 'Reds')

# %% [markdown]
# - 와웅! 문제가 해결됐다!!!
# - 이제 네모 박스의 크기를 수정해보자.

# %% [markdown]
# ## 2. 시각화 그래프 사이즈 수정

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.heatmap(test, cbar = True, annot = True, annot_kws = {'size':20}, square = True, cmap = 'Reds', ax = ax)

# %% [markdown]
# - 위에서 봤던 그래프보다 크기가 훨씬 커져서 보기도 편하다.
#
# ---
#
# - 시각화하여 데이터를 확인하니, 수치만으로 보는 것보다 훨씬 직관적이다.
# - 시각화의 소중함을 다시 한번 깨닫는다 :)
